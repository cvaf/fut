# %%
import pandas as pd
import numpy as np

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use(['seaborn-muted', 'dark_background'])
plt.style.use(['seaborn-muted'])
# %matplotlib inline

# other
from datetime import datetime, timedelta

# %% [markdown]
# # Model Evaluation

# %%
df = pd.read_pickle('../data/model_preds.pkl')

for col in df.columns:
    df[col] = df[col].astype(int)
    
start_date = datetime(2019, 9, 20)
for i in range(1, 4):
    df['date{}'.format(i)] = start_date + df['day{}'.format(i)].apply(timedelta)
    df['error{}'.format(i)] = df['pred{}'.format(i)] - df['target{}'.format(i)]

# %%
df_players = pd.read_pickle('../data/fifa20_players.pkl')
df_players['resource_id'] = df_players.resource_id.astype(int)

df = df.merge(df_players[['resource_id', 'player_name', 'overall', 'position', 'club', 'league', 'nationality']], on=['resource_id'], how='left')

# %%
df.head(2)
# Out:
#    pred1  pred2  pred3  target1  target2  target3  day1  day2  day3  \
# 0   8971   9501   9426     5780     5771     5654    10    11    11
# 1   9246   9771   9698     5771     5654     5914    11    11    13
#
#    resource_id  ...      date2  error2      date3  error3         player_name  \
# 0        41236  ... 2019-10-01    3730 2019-10-01    3772  Zlatan Ibrahimovic
# 1        41236  ... 2019-10-01    4117 2019-10-03    3784  Zlatan Ibrahimovic
#
#    overall position       club               league nationality
# 0       85       ST  LA Galaxy  Major League Soccer      Sweden
# 1       85       ST  LA Galaxy  Major League Soccer      Sweden
#
# [2 rows x 22 columns]

# %% [markdown]
# ### General Visualizations

# %%
fig, axs = plt.subplots(1,3, figsize=(18,6))

for i, ax in enumerate(axs):
    sns.distplot(df['error{}'.format(i+1)], ax=ax)

# %% [markdown]
# ### First error

# %%
fig, axs = plt.subplots(1,3, figsize=(24, 8))

for ovr in np.arange(85, 90):
    df_ = df[df.overall==str(ovr)]
    
    sns.distplot(df_.error1, ax=axs[0], label=ovr)
    
for ovr in [84, 88, 92]:
    df_ = df[df.overall==str(ovr)]
    sns.distplot(df_.error1, ax=axs[1], label=ovr)
    
for ovr in [84, 85, 86]:
    df_ = df[df.overall==str(ovr)]
    sns.distplot(df_.error1, ax=axs[2], label=ovr)
    
axs[0].legend()
axs[1].legend()
axs[2].legend()
plt.show()

# %%
df['abs_error1'] = abs(df.error1)

error1 = df.groupby('resource_id').agg({'abs_error1': ['mean', 'std']}).reset_index()

error1 = error1.merge(df_players, on='resource_id', how='left')

error1 = error1.merge(df.groupby('resource_id').target1.mean().reset_index().rename({'target1': 'price'}, axis=1), on='resource_id', how='left')

error1['mean_error'] = error1[error1.columns[2]]
error1['std_error'] = error1[error1.columns[3]]

error1 = error1[['resource_id', 'player_id', 'player_name', 'overall', 'position', 'club', 'nationality', 'league', 'price', 'mean_error', 'std_error']]

error1['scaled_mean_error'] = error1.mean_error / error1.price
error1['scaled_std_error'] = error1.std_error / error1.price
# Out:
# /home/costas/.virtualenvs/fut/lib/python3.8/site-packages/pandas/core/reshape/merge.py:617: UserWarning: merging between different levels can give an unintended result (2 levels on the left, 1 on the right)
#   warnings.warn(msg, UserWarning)

# %%
error1.head(2)
# Out:
#    resource_id player_id         player_name overall position       club  \
# 0        41236      4071  Zlatan Ibrahimovic      85       ST  LA Galaxy
# 1       120533     24236                Pepe      84       CB   FC Porto
#
#   nationality               league       price   mean_error    std_error  \
# 0      Sweden  Major League Soccer  7894.59596  2929.646465  1347.952100
# 1    Portugal             Liga NOS  5206.50000  3653.394231  1026.280204
#
#    scaled_mean_error  scaled_std_error
# 0           0.371095          0.170744
# 1           0.701699          0.197115

# %%
error1.sort_values(by='scaled_mean_error', ascending=True).head(40)
# Out:
#      resource_id player_id         player_name overall position  \
# 133     50471368     44020     Vincent Kompany      85       CB
# 334     67312240     42999     Virgil van Dijk      90       CB
# 139     50489129     43974         Raúl Albiol      85       CB
# 245     50542948     43757     Anthony Martial      86       LW
# 209     50531752     43037       Heung Min Son      87       CF
# 195     50524633     42993     Kevin De Bruyne      91      CAM
# 254     50547562     43009        N'Golo Kanté      89      CDM
# 390     84084790     42985     James Rodríguez      88      CAM
# 236     50540370     43024          Sadio Mané      88       LW
# 462    151183489     43864  Robert Lewandowski      92       ST
# 237     50540979     42998       Mohamed Salah      90       RW
# 295     67292141     42995         Eden Hazard      91       LW
# 315     67301849     42842     Kevin De Bruyne      92       CM
# 385     84075322     42845            Coutinho      87      CAM
# 458    134421104     43922     Virgil van Dijk      91       CB
# 464    151203666     43881          Sadio Mané      90       LM
# 346     67318522     43758       Leon Goretzka      87       CM
# 444    117633017     44027       Romelu Lukaku      87       ST
# 113       215914       386        N'Golo Kanté      89      CDM
# 307     67298460     42982       Thomas Müller      88      CAM
# 375     67348994     43697        Éder Militão      86       CB
# 257     50548242     43830         Nabil Fekir      86       RM
# 448    117651622     43704        Paulo Dybala      90      CAM
# 37        183277       385         Eden Hazard      91       LW
# 454    134410713     43976     Kevin De Bruyne      94      CAM
# 89        203376       469     Virgil van Dijk      90       CB
# 99        208722       466          Sadio Mané      88       LW
# 330     67310806     43630     Roberto Firmino      88       CF
# 447    117649234     43930          Sadio Mané      89       LW
# 403     84095411     43925       Mohamed Salah      91       RW
# 409     84101994     43913        N'Golo Kanté      90      CDM
# 351     67319981     42978           Dele Alli      87      CAM
# 286     67284807     42184       Dries Mertens      88       ST
# 301     67297214     43919          Marco Reus      89      CAM
# 79        200104       525       Heung Min Son      87       CF
# 262     50555607     43752      Lucas Torreira      86      CDM
# 305     67298196     43756          Jordi Alba      89       LB
# 100       209331       461       Mohamed Salah      90       RW
# 423    100863943     44035        Josip Ilicic      87       ST
# 407     84100036     43637               Adama      85       RW
#
#                         club     nationality              league  \
# 133           RSC Anderlecht         Belgium  Belgium Pro League
# 334                Liverpool         Holland      Premier League
# 139            Villarreal CF           Spain    LaLiga Santander
# 245        Manchester United          France      Premier League
# 209        Tottenham Hotspur  Korea Republic      Premier League
# 195          Manchester City         Belgium      Premier League
# 254                  Chelsea          France      Premier League
# 390              Real Madrid        Colombia    LaLiga Santander
# 236                Liverpool         Senegal      Premier League
# 462        FC Bayern München          Poland          Bundesliga
# 237                Liverpool           Egypt      Premier League
# 295              Real Madrid         Belgium    LaLiga Santander
# 315          Manchester City         Belgium      Premier League
# 385        FC Bayern München          Brazil          Bundesliga
# 458                Liverpool         Holland      Premier League
# 464                Liverpool         Senegal      Premier League
# 346        FC Bayern München         Germany          Bundesliga
# 444                    Inter         Belgium         Serie A TIM
# 113                  Chelsea          France      Premier League
# 307        FC Bayern München         Germany          Bundesliga
# 375              Real Madrid          Brazil    LaLiga Santander
# 257               Real Betis          France    LaLiga Santander
# 448          Piemonte Calcio       Argentina         Serie A TIM
# 37               Real Madrid         Belgium    LaLiga Santander
# 454          Manchester City         Belgium      Premier League
# 89                 Liverpool         Holland      Premier League
# 99                 Liverpool         Senegal      Premier League
# 330                Liverpool          Brazil      Premier League
# 447                Liverpool         Senegal      Premier League
# 403                Liverpool           Egypt      Premier League
# 409                  Chelsea          France      Premier League
# 351        Tottenham Hotspur         England      Premier League
# 286                   Napoli         Belgium         Serie A TIM
# 301        Borussia Dortmund         Germany          Bundesliga
# 79         Tottenham Hotspur  Korea Republic      Premier League
# 262                  Arsenal         Uruguay      Premier League
# 305             FC Barcelona           Spain    LaLiga Santander
# 100                Liverpool           Egypt      Premier League
# 423                 Atalanta        Slovenia         Serie A TIM
# 407  Wolverhampton Wanderers           Spain      Premier League
#
#              price    mean_error     std_error  scaled_mean_error  \
# 133   17752.428571    189.428571    118.073222           0.010671
# 334  553362.690141   9667.577465   7408.990623           0.017471
# 139   18575.357143    351.428571    337.306004           0.018919
# 245  543095.425532  10815.191489  11648.069248           0.019914
# 209  442933.126761   9692.929577   6985.470104           0.021884
# 195  242021.098592   5340.140845   4796.015016           0.022065
# 254  329418.788732   7295.704225   5130.697211           0.022147
# 390  266516.626667   6114.493333   5473.668577           0.022942
# 236  306190.338028   7272.563380   7266.071219           0.023752
# 462  221272.038462   5260.615385   3226.553543           0.023774
# 237  248425.591549   5961.971831   4402.334491           0.023999
# 295  318882.352113   7738.633803   6692.775880           0.024268
# 315  477105.744898  11605.908163  12296.598552           0.024326
# 385  351596.051020   8712.765306   8243.766693           0.024781
# 458  668474.157895  16600.842105  18934.895687           0.024834
# 464  557581.761905  14500.476190  11865.842215           0.026006
# 346  687865.744681  17926.702128  15966.250651           0.026061
# 444   29460.857143    771.285714    494.288618           0.026180
# 113  332625.192308   8732.509615   6742.335078           0.026253
# 307  190100.746667   5016.106667   4257.245638           0.026387
# 375  604651.685185  16372.833333  14640.792142           0.027078
# 257   28051.178571    760.642857    584.586540           0.027116
# 448  671752.740741  18782.629630  19684.061302           0.027961
# 37   370001.086538  10522.221154   7025.521155           0.028438
# 454  723544.928571  20878.000000  16994.859761           0.028855
# 89   566683.951923  16520.432692   9583.804806           0.029153
# 99   323671.920000   9679.220000   7834.114288           0.029904
# 330  799694.352941  24046.470588  14964.453929           0.030070
# 447  374564.133333  11273.666667   8197.770809           0.030098
# 403  348299.315789  10588.315789   8309.503856           0.030400
# 409  359564.368421  10972.052632   7843.508905           0.030515
# 351  212846.120000   6678.933333   5466.231310           0.031379
# 286  376493.682692  11851.423077  13839.127774           0.031478
# 301  266942.266667   8507.933333   6871.330433           0.031872
# 79   462191.278846  14740.769231   8633.552185           0.031893
# 262  189662.957447   6076.212766   4883.316892           0.032037
# 305  639432.659574  20902.170213  17333.095658           0.032689
# 100  279211.721154   9155.980769   5901.471019           0.032792
# 423   30137.571429    995.142857    536.391470           0.033020
# 407  263433.529412   8806.338235   7823.188008           0.033429
#
#      scaled_std_error
# 133          0.006651
# 334          0.013389
# 139          0.018159
# 245          0.021448
# 209          0.015771
# 195          0.019817
# 254          0.015575
# 390          0.020538
# 236          0.023731
# 462          0.014582
# 237          0.017721
# 295          0.020988
# 315          0.025773
# 385          0.023447
# 458          0.028326
# 464          0.021281
# 346          0.023211
# 444          0.016778
# 113          0.020270
# 307          0.022395
# 375          0.024214
# 257          0.020840
# 448          0.029303
# 37           0.018988
# 454          0.023488
# 89           0.016912
# 99           0.024204
# 330          0.018713
# 447          0.021886
# 403          0.023857
# 409          0.021814
# 351          0.025682
# 286          0.036758
# 301          0.025741
# 79           0.018680
# 262          0.025747
# 305          0.027107
# 100          0.021136
# 423          0.017798
# 407          0.029697

# %%
rids = [67312240, 50542948, 50531752, 50524633]

# %%
def plot_pred(rids, step=1):
    num_rids = len(rids)
    fig, axs = plt.subplots(1, num_rids, figsize=(6*num_rids, 6))
    for i, ax in enumerate(axs):
        rid = rids[i]
    
        player_name = df[df.resource_id==rid].player_name.values[0]
        player_ovr = df[df.resource_id==rid].overall.values[0]

        cols = ['pred{}'.format(step), 'target{}'.format(step), 'date{}'.format(step)]
        df_ = df[df.resource_id==rid][cols]

        ax.plot(df_[cols[2]], df_[cols[0]], label='Prediction')
        ax.plot(df_[cols[2]], df_[cols[1]], label='Actual price')

        ax.set_title(str(player_ovr) + ' ' +  player_name + '; Step: {}'.format(step))
        ax.tick_params(axis='x', rotation=45)

        ax.legend()
    plt.show()

# %%
plot_pred(rids, step=1)
plot_pred(rids, step=2)
plot_pred(rids, step=3)
