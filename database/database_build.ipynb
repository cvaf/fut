# %%
## import pandas as pd
import numpy as np
from datetime import datetime

import warnings
warnings.filterwarnings('ignore')

# custom functions for pulling
from db_functions import *

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Player Database
#
# We start by loading our data and removing some variables we don't need.

# %%
df = pd.read_csv('FIFA19 - Ultimate Team players.csv', low_memory = False)
cols_drop = ['origin', 'player_extended_name', 'price_xbox', 'price_pc', 'specialties', 'cb', 'lb', 'rb', 'rwb', 'lwb', 'cdm', 'cm', 'cam', 'lm', 'lw', 'lf', 'rm', 'rw', 'rf', 'cf', 'st', 
                   'price_ps4', 'gk_positoning', 'gk_kicking', 'gk_speed', 'gk_handling', 'gk_reflexes', 'gk_diving', 'date_of_birth', 'traits']
df.drop(cols_drop, axis = 1, inplace = True)
df = df[(df.quality == 'Gold - Rare') | (df.quality == 'Gold')]
df.reset_index(drop = True, inplace = True)
df['resource_id'] = np.nan
df['id'] = df.player_ID
df.set_index('id', inplace = True)

# %%
df.tail(2)
# Out:
#        player_ID     player_name      quality revision  overall  \
# id
# 17020      17020  Gelson Martins  Gold - Rare      SBC       82
# 17021      17021           Verdi  Gold - Rare      OTW       81
#
#                   club            league nationality position  age  height  \
# id
# 17020  Atlético Madrid  LaLiga Santander    Portugal       RM   23     173
# 17021           Napoli       Serie A TIM       Italy       RW   26     171
#
#        weight  intl_rep  added_date  pace  pace_acceleration  \
# id
# 17020      72         3  2018-10-05  94.0                 95
# 17021      61         2  2018-10-05  87.0                 88
#
#        pace_sprint_speed  dribbling  drib_agility  drib_balance  \
# id
# 17020                 94       86.0            94            92
# 17021                 86       85.0            92            90
#
#        drib_reactions  drib_ball_control  drib_dribbling  drib_composure  \
# id
# 17020              83                 83              85              85
# 17021              78                 86              84              78
#
#        shooting  shoot_positioning  shoot_finishing  shoot_shot_power  \
# id
# 17020      69.0                 82               66                72
# 17021      73.0                 76               67                81
#
#        shoot_long_shots  shoot_volleys  shoot_penalties  passing  pass_vision  \
# id
# 17020                69             74               66     75.0           79
# 17021                77             74               68     81.0           82
#
#        pass_crossing  pass_free_kick  pass_short  pass_long  pass_curve  \
# id
# 17020             81              60          78         55          82
# 17021             82              84          82         76          84
#
#        defending  def_interceptions  def_heading  def_marking  \
# id
# 17020       47.0                 43           51           54
# 17021       48.0                 36           42           55
#
#        def_stand_tackle  def_slid_tackle  physicality  phys_jumping  \
# id
# 17020                46               36         61.0            65
# 17021                48               60         55.0            51
#
#        phys_stamina  phys_strength  phys_aggression pref_foot att_workrate  \
# id
# 17020            87             48               60     Right         High
# 17021            75             48               48      Left         High
#
#       def_workrate  weak_foot  skill_moves  resource_id
# id
# 17020          Med          3            5          NaN
# 17021          Med          5            4          NaN

# %%
print('As of now, we have {} players in our database and no prices.'.format(df.shape[0]))
print('Our data consists of {} features.'.format(df.shape[1]))
# Out:
# As of now, we have 2920 players in our database and no prices.
# Our data consists of 55 features.

# %% [markdown]
# # Data Mining
#
# We wish to add all the gold players (including special cards) along with daily prices. To do so, we need to do the following:
# 1. Scrape futbin and collect the resource id for every player listed above, and add that to our dataframe.
# 2. Build a script that adds all the new players that are not in our dataframe (collects all relevant data including the resource id).
# 3. Collect the prices on all the players in our database using the resource id. Construct multiple observations for each player, one for each price-point.
#
#
# #### Step 1
#
# To scrape the resource id, we will be using some functions defined below that use requests and beautiful soup to parse the html of each player's page on futbin.

# %%
df_p = df_fetch_resourceid(df)

# %% [markdown]
# Turns out, we also need the PGP data for each player, so we parse that too.

# %%
df_p = df_p.groupby('player_ID').last()
df_p['num_games'] = np.nan
df_p['avg_goals'] = np.nan
df_p['avg_assists'] = np.nan

# %%
df_players = df_fetch_pgp(df_players)

# %% [markdown]
# #### Step 2
#
# We have collected the resource_id for the players in our dataframe. To proceed, we're going to write some functions to collect data on players that are not in our dataframe and add them.

# %%
df_p = df_fetch_newplayers(17503, df_p)

# %% [markdown]
# Before we move on to step 3, we should filter our constructed dataframe s.t we only keep the players we are actually interested in.
# We remove:
# - Goalkeepers
# - Silver players
# - Bronze players
#
# There are various players that are not unavailable to be purchased, e.g. Flashback SBC players, but those will be dealt with later.

# %%
df_p = df_p[(df_p.quality == 'Gold - Rare') | (df_p.quality == 'Gold') | (df_p.quality == 'gold rare')]
df_p['revision'] = df_p.revision.fillna('Normal')
df_p = df_p[df_p.position != 'GK']

# %% [markdown]
# #### Player Database is Ready
#
# We save the player database before proceeding to getting the prices for each player.

# %%
df_p.to_csv('player_database.csv')

# %% [markdown]
# We now fetch the prices for each player in our database. This process will probably take long, depending on the size of the player database.

# %%
df_prices = df_fetch_price(df_p)

# %%
df_prices.to_csv('prices_database.csv')

# %% [markdown]
# # Dataframe Update
#
# To update our dataframe when new players are added to the game, we do the following:
# - Read in our player dataframe
# - Scrape the data for all the new players
# - Fetch their prices

# %%
df_p = pd.read_csv('data/player_database.csv', index_col='player_ID', parse_dates=['added_date'])
# df_p.drop('player_ID.1', inplace=True, axis=1)
df_p = df_fetch_newplayers(20777, df_p)
# Out:
# Completed 1 players. Time elapsed: 1 seconds.
# Approximate time left: 2041 seconds.
# No player found at ID: 18744.
# No player found at ID: 18754.
# No player found at ID: 18755.
# No player found at ID: 18758.
# No player found at ID: 18778.
# No player found at ID: 18798.
# No player found at ID: 18807.
# No player found at ID: 18833.
# No player found at ID: 18857.
# No player found at ID: 18858.
# No player found at ID: 18862.
# No player found at ID: 18874.
# No player found at ID: 18893.
# No player found at ID: 18897.
# Completed 200 players. Time elapsed: 238 seconds.
# Approximate time left: 2191 seconds.
# No player found at ID: 18956.
# No player found at ID: 18957.
# No player found at ID: 18971.
# No player found at ID: 18981.
# No player found at ID: 19008.
# No player found at ID: 19035.
# No player found at ID: 19065.
# No player found at ID: 19090.
# No player found at ID: 19106.
# No player found at ID: 19107.
# No player found at ID: 19119.
# No player found at ID: 19124.
# Completed 400 players. Time elapsed: 472 seconds.
# Approximate time left: 1937 seconds.
# No player found at ID: 19136.
# No player found at ID: 19180.
# No player found at ID: 19195.
# No player found at ID: 19217.
# No player found at ID: 19219.
# No player found at ID: 19239.
# No player found at ID: 19242.
# No player found at ID: 19257.
# No player found at ID: 19259.
# No player found at ID: 19266.
# No player found at ID: 19271.
# No player found at ID: 19278.
# No player found at ID: 19297.
# No player found at ID: 19299.
# No player found at ID: 19308.
# No player found at ID: 19309.
# No player found at ID: 19310.
# No player found at ID: 19311.
# No player found at ID: 19312.
# No player found at ID: 19316.
# No player found at ID: 19327.
# No player found at ID: 19335.
# Completed 600 players. Time elapsed: 700 seconds.
# Approximate time left: 1682 seconds.
# No player found at ID: 19343.
# No player found at ID: 19354.
# No player found at ID: 19356.
# No player found at ID: 19394.
# No player found at ID: 19427.
# No player found at ID: 19430.
# No player found at ID: 19444.
# No player found at ID: 19447.
# No player found at ID: 19469.
# No player found at ID: 19470.
# No player found at ID: 19525.
# Completed 800 players. Time elapsed: 933 seconds.
# Approximate time left: 1448 seconds.
# No player found at ID: 19549.
# No player found at ID: 19559.
# No player found at ID: 19561.
# No player found at ID: 19585.
# No player found at ID: 19589.
# No player found at ID: 19596.
# No player found at ID: 19604.
# No player found at ID: 19616.
# No player found at ID: 19619.
# No player found at ID: 19633.
# No player found at ID: 19645.
# No player found at ID: 19665.
# No player found at ID: 19668.
# No player found at ID: 19670.
# No player found at ID: 19671.
# No player found at ID: 19672.
# No player found at ID: 19673.
# No player found at ID: 19674.
# No player found at ID: 19675.
# No player found at ID: 19676.
# No player found at ID: 19677.
# No player found at ID: 19678.
# No player found at ID: 19679.
# No player found at ID: 19680.
# No player found at ID: 19681.
# No player found at ID: 19682.
# No player found at ID: 19683.
# No player found at ID: 19684.
# No player found at ID: 19689.
# No player found at ID: 19692.
# No player found at ID: 19714.
# No player found at ID: 19715.
# No player found at ID: 19735.
# Completed 1000 players. Time elapsed: 1183 seconds.
# Approximate time left: 1232 seconds.
# No player found at ID: 19739.
# No player found at ID: 19740.
# No player found at ID: 19748.
# No player found at ID: 19755.
# No player found at ID: 19758.
# No player found at ID: 19759.
# No player found at ID: 19778.
# No player found at ID: 19826.
# No player found at ID: 19855.
# No player found at ID: 19860.
# No player found at ID: 19876.
# No player found at ID: 19877.
# No player found at ID: 19907.
# No player found at ID: 19923.
# No player found at ID: 19928.
# No player found at ID: 19932.
# No player found at ID: 19934.
# Completed 1200 players. Time elapsed: 1426 seconds.
# Approximate time left: 1000 seconds.
# No player found at ID: 19937.
# No player found at ID: 19938.
# No player found at ID: 19939.
# No player found at ID: 19964.
# No player found at ID: 19976.
# No player found at ID: 19987.
# No player found at ID: 20034.
# No player found at ID: 20035.
# No player found at ID: 20054.
# No player found at ID: 20064.
# No player found at ID: 20066.
# No player found at ID: 20067.
# No player found at ID: 20071.
# No player found at ID: 20074.
# No player found at ID: 20076.
# No player found at ID: 20079.
# No player found at ID: 20084.
# No player found at ID: 20092.
# No player found at ID: 20109.
# No player found at ID: 20119.
# No player found at ID: 20121.
# No player found at ID: 20127.
# Completed 1400 players. Time elapsed: 1682 seconds.
# Approximate time left: 771 seconds.
# No player found at ID: 20139.
# No player found at ID: 20147.
# No player found at ID: 20158.
# No player found at ID: 20178.
# No player found at ID: 20185.
# No player found at ID: 20188.
# No player found at ID: 20189.
# No player found at ID: 20192.
# No player found at ID: 20197.
# No player found at ID: 20233.
# No player found at ID: 20244.
# No player found at ID: 20246.
# No player found at ID: 20247.
# No player found at ID: 20278.
# No player found at ID: 20289.
# No player found at ID: 20290.
# No player found at ID: 20298.
# No player found at ID: 20313.
# No player found at ID: 20314.
# No player found at ID: 20317.
# No player found at ID: 20321.
# No player found at ID: 20324.
# No player found at ID: 20329.
# No player found at ID: 20330.
# Completed 1600 players. Time elapsed: 1945 seconds.
# Approximate time left: 537 seconds.
# No player found at ID: 20362.
# No player found at ID: 20370.
# No player found at ID: 20375.
# No player found at ID: 20393.
# No player found at ID: 20394.
# No player found at ID: 20404.
# No player found at ID: 20429.
# No player found at ID: 20440.
# No player found at ID: 20447.
# No player found at ID: 20455.
# No player found at ID: 20464.
# No player found at ID: 20480.
# No player found at ID: 20490.
# No player found at ID: 20508.
# No player found at ID: 20525.
# No player found at ID: 20527.
# Completed 1800 players. Time elapsed: 2185 seconds.
# Approximate time left: 293 seconds.
# No player found at ID: 20538.
# No player found at ID: 20551.
# No player found at ID: 20556.
# No player found at ID: 20557.
# No player found at ID: 20581.
# No player found at ID: 20582.
# No player found at ID: 20615.
# No player found at ID: 20626.
# No player found at ID: 20627.
# No player found at ID: 20650.
# No player found at ID: 20651.
# No player found at ID: 20670.
# No player found at ID: 20671.
# No player found at ID: 20679.
# No player found at ID: 20691.
# No player found at ID: 20692.
# No player found at ID: 20698.
# No player found at ID: 20699.
# No player found at ID: 20726.
# Completed 2000 players. Time elapsed: 2422 seconds.
# Approximate time left: 50 seconds.
# No player found at ID: 20743.
# No player found at ID: 20750.
# No player found at ID: 20759.
# No player found at ID: 20761.
# No player found at ID: 20762.
# No player found at ID: 20763.
# No player found at ID: 20773.

# %%
df_p.tail(2)
# Out:
#                player_name    quality          revision overall  \
# player_ID
# 20776             Williams  gold rare  TOTS Moments SBC      91
# 20777      Clément Lenglet  gold rare  TOTS Moments SBC      88
#
#                     club            league nationality position age height  \
# player_ID
# 20776      Athletic Club  LaLiga Santander       Spain       ST  24    186
# 20777       FC Barcelona  LaLiga Santander      France       CB  23    186
#
#           weight intl_rep  added_date  pace  pace_acceleration  \
# player_ID
# 20776         79        2  2019-06-02  99.0                 97
# 20777         81        1  2019-06-03  81.0                 79
#
#            pace_sprint_speed  dribbling  drib_agility  drib_balance  \
# player_ID
# 20776                     99       92.0            93            64
# 20777                     81       75.0            69            67
#
#            drib_reactions  drib_ball_control  drib_dribbling  drib_composure  \
# player_ID
# 20776                  90                 94              95              82
# 20777                  88                 85              67              82
#
#            shooting  shoot_positioning  shoot_finishing  shoot_shot_power  \
# player_ID
# 20776          93.0                 90               91                99
# 20777          42.0                 56               27                69
#
#            shoot_long_shots  shoot_volleys  shoot_penalties  passing  \
# player_ID
# 20776                    93             81               76     87.0
# 20777                    42             28               51     68.0
#
#            pass_vision  pass_crossing  pass_free_kick  pass_short  pass_long  \
# player_ID
# 20776               89             92              63          94         78
# 20777               69             41              31          89         79
#
#            pass_curve  defending  def_interceptions  def_heading  def_marking  \
# player_ID
# 20776              58       50.0                 25           85           63
# 20777              28       90.0                 87           83           96
#
#            def_stand_tackle  def_slid_tackle  physicality  phys_jumping  \
# player_ID
# 20776                    46               37         90.0            97
# 20777                    88               87         86.0            87
#
#            phys_stamina  phys_strength  phys_aggression pref_foot  \
# player_ID
# 20776                85             96               75     Right
# 20777                80             88               88      Left
#
#           att_workrate def_workrate weak_foot skill_moves resource_id  \
# player_ID
# 20776             High         High         3           4   134433929
# 20777              Med         High         4           2   100883736
#
#           num_games avg_goals avg_assists
# player_ID
# 20776           113      0.71        0.45
# 20777            21      0.05        0.00

# %%
df_p = df_p[(df_p.quality == 'Gold - Rare') | (df_p.quality == 'Gold') | (df_p.quality == 'gold rare')]
df_p['revision'] = df_p.revision.fillna('Normal')
df_p = df_p[df_p.position != 'GK']
df_p.to_csv('data/player_database.csv')

# %%
df_prices = df_fetch_price(df_p)
# Out:
# Completed 1 players. Time elapsed: 0 seconds. Approx. 0 seconds left.
# Completed 200 players. Time elapsed: 100 seconds. Approx. 1834 seconds left.
# Completed 400 players. Time elapsed: 202 seconds. Approx. 1742 seconds left.
# Completed 600 players. Time elapsed: 303 seconds. Approx. 1641 seconds left.
# Completed 800 players. Time elapsed: 404 seconds. Approx. 1525 seconds left.
# Completed 1000 players. Time elapsed: 508 seconds. Approx. 1482 seconds left.
# Completed 1200 players. Time elapsed: 612 seconds. Approx. 1365 seconds left.
# Completed 1400 players. Time elapsed: 714 seconds. Approx. 1250 seconds left.
# Completed 1600 players. Time elapsed: 815 seconds. Approx. 1125 seconds left.
# Completed 1800 players. Time elapsed: 917 seconds. Approx. 1046 seconds left.
# Completed 2000 players. Time elapsed: 1022 seconds. Approx. 962 seconds left.
# Completed 2200 players. Time elapsed: 1125 seconds. Approx. 842 seconds left.
# Completed 2400 players. Time elapsed: 1227 seconds. Approx. 740 seconds left.
# Completed 2600 players. Time elapsed: 1332 seconds. Approx. 656 seconds left.
# No prices available for player with the following resource_id: 84106934.
# Completed 2800 players. Time elapsed: 1436 seconds. Approx. 541 seconds left.
# Completed 3000 players. Time elapsed: 1543 seconds. Approx. 451 seconds left.
# Completed 3200 players. Time elapsed: 1645 seconds. Approx. 332 seconds left.
# Completed 3400 players. Time elapsed: 1750 seconds. Approx. 234 seconds left.
# Completed 3600 players. Time elapsed: 1853 seconds. Approx. 129 seconds left.
# Completed 3800 players. Time elapsed: 1952 seconds. Approx. 24 seconds left.
# No prices available for player with the following resource_id: 50512746.
# No prices available for player with the following resource_id: 84098696.
# No prices available for player with the following resource_id: 67267489.
# No prices available for player with the following resource_id: 67353233.
# No prices available for player with the following resource_id: 50385562.
# No prices available for player with the following resource_id: 67299408.
# No prices available for player with the following resource_id: 50525877.
# No prices available for player with the following resource_id: 83939382.
# No prices available for player with the following resource_id: 67303592.
# No prices available for player with the following resource_id: 117639462.
# No prices available for player with the following resource_id: 50563903.
# No prices available for player with the following resource_id: 100875819.
# No prices available for player with the following resource_id: 167972264.
# No prices available for player with the following resource_id: 50509935.
# No prices available for player with the following resource_id: 84094910.
# No prices available for player with the following resource_id: 50573555.
# No prices available for player with the following resource_id: 100863943.
# No prices available for player with the following resource_id: 67342595.
# No prices available for player with the following resource_id: 151183489.

# %%
df_prices.tail(2)
# Out:
#           player_name    quality revision overall                       club  \
# 631539    Carlos Vela  gold rare               88  Los Angeles Football Club
# 631540  Karim Benzema  gold rare   CL SBC      90                Real Madrid
#
#                      league nationality position age height weight intl_rep  \
# 631539  Major League Soccer      Mexico       RW  30    177     77        3
# 631540     LaLiga Santander      France       ST  31    185     81        4
#
#         added_date  pace  pace_acceleration  pace_sprint_speed  dribbling  \
# 631539  2019-04-09  88.0                 86                 89       89.0
# 631540  2019-04-09  84.0                 84                 84       90.0
#
#         drib_agility  drib_balance  drib_reactions  drib_ball_control  \
# 631539            84            84              84                 90
# 631540            84            67              92                 94
#
#         drib_dribbling  drib_composure  shooting  shoot_positioning  \
# 631539              91              86      89.0                 91
# 631540              90              87      89.0                 95
#
#         shoot_finishing  shoot_shot_power  shoot_long_shots  shoot_volleys  \
# 631539               91                82                90             92
# 631540               87                91                84             87
#
#         shoot_penalties  passing  pass_vision  pass_crossing  pass_free_kick  \
# 631539               81     88.0           92             90              81
# 631540               92     86.0           95             84              82
#
#         pass_short  pass_long  pass_curve  defending  def_interceptions  \
# 631539          92         72          90       39.0                 45
# 631540          92         62          89       35.0                 24
#
#         def_heading  def_marking  def_stand_tackle  def_slid_tackle  \
# 631539           85           37                26               17
# 631540           85           51                16               13
#
#         physicality  phys_jumping  phys_stamina  phys_strength  \
# 631539         74.0            77            76             76
# 631540         86.0            80            82             91
#
#         phys_aggression pref_foot att_workrate def_workrate weak_foot  \
# 631539               64      Left         High          Low         2
# 631540               74     Right          Med          Low         4
#
#        skill_moves resource_id num_games avg_goals avg_assists        date  \
# 631539           4   117609928        12      0.25        0.08  2019-04-08
# 631540           4   134382881        14      0.93        0.57  2019-04-08
#
#         price
# 631539      0
# 631540      0

# %%
df_prices.to_csv('data/prices_database.csv')
