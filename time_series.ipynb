# %%
import pandas as pd
import numpy as np


# plotting
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 100)

# other
from datetime import datetime

# %% [markdown]
# # Time Series

# %%
df = pd.read_csv('data/prices_database.csv', index_col='Unnamed: 0', parse_dates=['added_date', 'date'])
df.head(2)
# Out:
#   player_name      quality revision  overall   club league nationality  \
# 0        Pelé  Gold - Rare     Icon       98  Icons  Icons      Brazil
# 1        Pelé  Gold - Rare     Icon       98  Icons  Icons      Brazil
#
#   position  age  height  weight  intl_rep added_date  pace  pace_acceleration  \
# 0      CAM   77     173      70         0 2018-09-19  95.0                 95
# 1      CAM   77     173      70         0 2018-09-19  95.0                 95
#
#    pace_sprint_speed  dribbling  drib_agility  drib_balance  drib_reactions  \
# 0                 95       96.0            94            93              98
# 1                 95       96.0            94            93              98
#
#    drib_ball_control  drib_dribbling  drib_composure  shooting  \
# 0                 97              96              98      96.0
# 1                 97              96              98      96.0
#
#    shoot_positioning  shoot_finishing  shoot_shot_power  shoot_long_shots  \
# 0                 97               98                94                94
# 1                 97               98                94                94
#
#    shoot_volleys  shoot_penalties  passing  pass_vision  pass_crossing  \
# 0             95               93     93.0           97             90
# 1             95               93     93.0           97             90
#
#    pass_free_kick  pass_short  pass_long  pass_curve  defending  \
# 0              89          96         88          89       60.0
# 1              89          96         88          89       60.0
#
#    def_interceptions  def_heading  def_marking  def_stand_tackle  \
# 0                 67           94           55                53
# 1                 67           94           55                53
#
#    def_slid_tackle  physicality  phys_jumping  phys_stamina  phys_strength  \
# 0               49         76.0            88            86             76
# 1               49         76.0            88            86             76
#
#    phys_aggression pref_foot att_workrate def_workrate  weak_foot  \
# 0               59     Right         High          Med          4
# 1               59     Right         High          Med          4
#
#    skill_moves  resource_id num_games avg_goals avg_assists       date  price
# 0            5       237067    12,719      0.69        0.41 2018-09-20      0
# 1            5       237067    12,719      0.69        0.41 2018-09-21      0

# %% [markdown]
# ### Data Processing
#
# We need to construct the following features:
# - available: Binary variable indicating the availability of the card on that given day
# - substitute: Binary variable indicating whether a new card for that player is available during that day. (SBC + Packs)
# - days: # of days available
# - promo: binary indicating if there's a promotion on that day.
# - weekday: 0-6 indicating the day of the week
# - month: 1-12
# - source: Whether the card was an SBC, Weekly OBJ or in packs.
#
# **Days**:

# %%
df['days'] = (df['date'] - df['added_date']).dt.days

# %% [markdown]
# Quick to note that some players have prices for the day before they were officially released, implying there's a mistake. Further investigation reveals that these should be offset to the next day instead.

# %%
offset_resources = df[df.days == -1].resource_id.unique()       # get resource id of users who match this 

df['date'] = np.where(df.resource_id.isin(offset_resources),    # remap the date variable
                      df.date +pd.DateOffset(days=1), df.date)
df['days'] = (df.date - df.added_date).dt.days                  # reassign the days variable

df = df[df.days >= 0]                                           # remove observations that have days < 0

# %% [markdown]
# **Weekday**:

# %%
df['weekday'] = df.date.dt.weekday                              # get the day of the week

# %% [markdown]
# **Month**:

# %%
df['month'] = df.date.dt.month

# %% [markdown]
# **Promo**:
#
# Promotional periods are the following:
# - TOTS: 10/5-21/6
# - Icon Release: 5/4-15/4
# - Fut Bday: 22/3-30/3
# - Carniball: 8/3-16/3
# - Rating Refresh: 15/2-24/2
# - Headliners: 1/2-8/2
# - Future Stars: 18/1-25/1
# - TOTY: 7/1-14/1
# - Futmas: 14/12-24/12
# - TOTGS: 7/12-14/12
# - Black Friday: 23/11-26/11
# - RTTF: 9/11-16/11
# - Halloween: 19/10-26/10

# %%
promos = [[datetime(2019, 5, 10), datetime(2019, 6, 21)],       # TOTS
          [datetime(2019, 4, 5), datetime(2019, 4, 15)],        # icon release
          [datetime(2019, 3, 22), datetime(2019, 3, 30)],       # fut bday
          [datetime(2019, 3, 8), datetime(2019, 3, 16)],        # carniball
          [datetime(2019, 2, 15), datetime(2019, 2, 24)],       # rating refresh
          [datetime(2019, 2, 1), datetime(2019, 2, 8)],         # headliners
          [datetime(2019, 1, 18), datetime(2019, 1, 25)],       # ffs
          [datetime(2019, 1, 7), datetime(2019, 1, 14)],        # TOTY
          [datetime(2018, 12, 14), datetime(2018, 12, 24)],     # futmas
          [datetime(2018, 12, 7), datetime(2018, 12, 14)],      # totgs
          [datetime(2018, 11, 23), datetime(2018, 11, 26)],     # black friday
          [datetime(2018, 11, 9), datetime(2018, 11, 16)],      # rttf
          [datetime(2018, 10, 19), datetime(2018, 10, 26)]]     # halloween

def promo_assignment(ds):
    date = pd.to_datetime(ds)
    promo = 0
    for p in promos:
        if (p[0] <= date) & (p[1] >= date):
            promo = 1
            break
    return promo

df['promo'] = df['date'].apply(promo_assignment)                # apply the promo assignment

# %% [markdown]
# **Card Source**:

# %%
df.revision.fillna('MLS POTM', inplace=True)

# %%
df['source'] = 'packs'
df['source'] = np.where(df.revision.str.contains('Normal') | df.revision.str.contains('Icon') | df.revision.str.contains('Refresh'),
                        'base', df.source)                                                                     # Base cards
df['source'] = np.where(df.revision.str.contains('SBC') | df.revision.str.contains('POTM'), 'sbc', df.source)  # SBC
df['source'] = np.where(df.revision.str.contains('Loan'), 'loan', df.source)                                   # Loans
df['source'] = np.where(df.revision.str.contains('Ob'), 'objective', df.source)                                # Objectives

df = df[df.source != 'loan']                                                                                   # remove loan cards

# %% [markdown]
# **Availability**:
# - Pack cards: will be labeled as available for a week after being added to the database. This isn't always accurate but an overall approximation.
# - SBC: Availability will also be set for a week - again, an approximation.
# - Objectives: Weekly availability
# - Winter Upgrades + Base Cards: Available throughout except periods where they have special cards in packs. Winter upgrades replace base cards.

# %%
df['available'] = np.nan

# special cards in packs, sbcs and objectives
df['available'] = np.where(((df.source == 'packs') | (df.source == 'sbc') | (df.source == 'objective')) & (df.date <= df.added_date + pd.DateOffset(7)),
                           1, df.available)

# %%
def in_packs(row):
    if row['source'] == 'base':
        p_name = row['player_name']
        age = row['age']
        height = row['height']
        weight = row['weight']
        intl_rep = row['intl_rep']
        date = row['date']
        if df[(df.player_name == p_name) & (df.age == age) 
               & (df.height == height) & (df.weight == weight) 
               & (df.intl_rep == intl_rep) & (df.date == date) 
               & (df.source == 'packs') & (df.available == 1)].shape[0] > 0:
            return 0
        else:
            return 1
    else:
        return row['available']

# %%
df.apply(in_packs, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-8262eea716c8> in <module>
# ----> 1 df.apply(in_packs, axis=1)
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6485                          args=args,
#    6486                          kwds=kwds)
# -> 6487         return op.get_result()
#    6488
#    6489     def applymap(self, func):
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\apply.py in get_result(self)
#     149             return self.apply_raw()
#     150
# --> 151         return self.apply_standard()
#     152
#     153     def apply_empty_result(self):
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     249                                           axis=self.axis,
#     250                                           dummy=dummy,
# --> 251                                           labels=labels)
#     252                 return self.obj._constructor_sliced(result, index=labels)
#     253             except Exception:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.reduce()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-92-d5cc58ff948a> in in_packs(row)
#      10                & (df.height == height) & (df.weight == weight)
#      11                & (df.intl_rep == intl_rep) & (df.date == date)
# ---> 12                & (df.source == 'packs') & (df.available == 1)].shape[0] > 0:
#      13             return 0
#      14         else:
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1772             res_values = com.values_from_object(res)
#    1773             return self._constructor(res_values, index=self.index,
# -> 1774                                      name=res_name, dtype='bool')
#    1775
#    1776     wrapper.__name__ = op_name
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     260             else:
#     261                 data = sanitize_array(data, index, dtype, copy,
# --> 262                                       raise_cast_failure=True)
#     263
#     264                 data = SingleBlockManager(data, index, fastpath=True)
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\internals\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     570                         subarr = data.copy()
#     571             else:
# --> 572                 subarr = _try_cast(data, True, dtype, copy, raise_cast_failure)
#     573         elif isinstance(data, Index):
#     574             # don't coerce Index types
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\internals\construction.py in _try_cast(arr, take_fast_path, dtype, copy, raise_cast_failure)
#     702                                        isinstance(subarr, np.ndarray))):
#     703             subarr = construct_1d_object_array_from_listlike(subarr)
# --> 704         elif not is_extension_type(subarr):
#     705             subarr = construct_1d_ndarray_preserving_na(subarr, dtype,
#     706                                                         copy=copy)
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\dtypes\common.py in is_extension_type(arr)
#    1691     """
#    1692
# -> 1693     if is_categorical(arr):
#    1694         return True
#    1695     elif is_sparse(arr):
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\dtypes\common.py in is_categorical(arr)
#     289     """
#     290
# --> 291     return isinstance(arr, ABCCategorical) or is_categorical_dtype(arr)
#     292
#     293
#
# c:\users\costa\envs\fut\lib\site-packages\pandas\core\dtypes\common.py in is_categorical_dtype(arr_or_dtype)
#     600     if arr_or_dtype is None:
#     601         return False
# --> 602     return CategoricalDtype.is_dtype(arr_or_dtype)
#     603
#     604
#
# KeyboardInterrupt:

# %% [markdown]
# Might be better to create a cross product / leftjoin of basecards and packscards and then mark availability accordingly.

# %% [markdown]
# **Substitute**:

# %%
df.revision.unique()
# Out:
# array(['Icon', 'Normal', 'IF', 'OTW', 'SBC', 'Europa Base',
#        'Swap Deal Reward SBC', 'PL POTM', 'Flashback SBC', 'Halloween',
#        'Bundes POTM', 'Halloween SBC', 'SIF', 'UCL LIVE', 'UEL LIVE',
#        'Award Winner', 'UEL LIVE SBC', 'TIF', 'TOTGS', 'Europa TOTGS',
#        'CL TOTT SBC', 'Hero', 'FUTmas SBC', 'FUTmas', 'TOTY',
#        'TOTY Nominee Loan', 'TOTY Nominee SBC', 'TOTY Nominee', 'CL',
#        'FUT Future Stars', 'SBC - Future Stars', 'Weekly Obj- FFS',
#        'Weekly Obj- FS', 'MOTM', 'Headliners SBC', 'Headliners',
#        'Headliners- Wk. Obj.', 'Premium SBC', 'Winter Refresh',
#        'Europa MOTM', 'CL MOTM', 'CL SBC', 'Europa SBC', 'Carniball',
#        'Carniball-SBC', 'Carniball-Wkly Obj', 'Carniball SBC', 'FIF',
#        'FUT Birthday SBC', 'FUT Birthday', 'FUT Birthday Wkly Ob',
#        'Award Winner Wkly Ob', nan], dtype=object)

# %%
df[df.revision.isnull()]
# Out:
#         player_name    quality revision  overall                       club  \
# 631539  Carlos Vela  gold rare      NaN       88  Los Angeles Football Club
#
#                      league nationality position  age  height  weight  \
# 631539  Major League Soccer      Mexico       RW   30     177      77
#
#         intl_rep added_date  pace  pace_acceleration  pace_sprint_speed  \
# 631539         3 2019-04-09  88.0                 86                 89
#
#         dribbling  drib_agility  drib_balance  drib_reactions  \
# 631539       89.0            84            84              84
#
#         drib_ball_control  drib_dribbling  drib_composure  shooting  \
# 631539                 90              91              86      89.0
#
#         shoot_positioning  shoot_finishing  shoot_shot_power  \
# 631539                 91               91                82
#
#         shoot_long_shots  shoot_volleys  shoot_penalties  passing  \
# 631539                90             92               81     88.0
#
#         pass_vision  pass_crossing  pass_free_kick  pass_short  pass_long  \
# 631539           92             90              81          92         72
#
#         pass_curve  defending  def_interceptions  def_heading  def_marking  \
# 631539          90       39.0                 45           85           37
#
#         def_stand_tackle  def_slid_tackle  physicality  phys_jumping  \
# 631539                26               17         74.0            77
#
#         phys_stamina  phys_strength  phys_aggression pref_foot att_workrate  \
# 631539            76             76               64      Left         High
#
#        def_workrate  weak_foot  skill_moves  resource_id num_games avg_goals  \
# 631539          Low          2            4    117609928        12      0.25
#
#        avg_assists       date  price  days  weekday  promo  month
# 631539        0.08 2019-04-09      0     0        1      1      4

# %%
df.date.max()
# Out:
# Timestamp('2019-04-09 00:00:00')

# %%
sub.head()
# Out:
#             player_name  age  height  weight  intl_rep  resource_id  \
# 0            Aaron Mooy   28     173      72         1     50526606
# 1          Aarón Martín   21     180      72         1       236295
# 2                 Abate   31     180      73         2       168312
# 3  Abderrazak Hamdallah   28     179      81         1     50545409
# 4    Abdoulaye Doucouré   26     182      76         2     50539783
#
#                         added_date
# 0  [2018-11-28T00:00:00.000000000]
# 1  [2018-09-19T00:00:00.000000000]
# 2  [2018-09-19T00:00:00.000000000]
# 3  [2018-12-19T00:00:00.000000000]
# 4  [2019-01-15T00:00:00.000000000]

# %%
df.groupby(['player_name', 'age', 'height', 'weight', 'intl_rep']).added_date.unique().reset_index().head()
# Out:
#             player_name  age  height  weight  intl_rep  \
# 0            Aaron Mooy   28     173      72         1
# 1          Aaron Ramsey   28     183      76         3
# 2          Aarón Martín   21     180      72         1
# 3                 Abate   31     180      73         2
# 4  Abderrazak Hamdallah   28     179      81         1
#
#                                           added_date
# 0                    [2018-11-28T00:00:00.000000000]
# 1                    [2019-04-06T00:00:00.000000000]
# 2                    [2018-09-19T00:00:00.000000000]
# 3                    [2018-09-19T00:00:00.000000000]
# 4  [2018-12-19T00:00:00.000000000, 2019-01-30T00:...

# %%
sub = df.groupby(['player_name', 'age', 'height', 'weight', 'intl_rep', 'resource_id']).added_date.unique().reset_index()

# %%
max_cards = df.groupby(['player_name', 'age', 'height', 'weight', 'intl_rep']).resource_id.nunique().max()

# %%
max_cards
# Out:
# 6

# %%
df.groupby(['player_name', 'age', 'height', 'weight', 'intl_rep']).resource_id.nunique()[df.groupby(['player_name', 'age', 'height', 'weight', 'intl_rep']).resource_id.nunique() == 6]

# %%
sub.added_date.shift(-2)
